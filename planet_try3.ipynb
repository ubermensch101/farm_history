# %%
import copy
import json
import math
import os
import pathlib
import time
import psycopg2
import requests
from requests.adapters import HTTPAdapter
from requests.auth import HTTPBasicAuth
from urllib3.util.retry import Retry

# %%
PL_API_KEY = 'PLAK721cf7576b5f4835bcd0f2dfe9a7a395'
ORDERS_API_URL = 'https://api.planet.com/compute/ops/orders/v2'
BASEMAP_API_URL = 'https://api.planet.com/basemaps/v1/mosaics'

SESSION = requests.Session()

SESSION.auth = (PL_API_KEY, '')
AUTH = HTTPBasicAuth(PL_API_KEY, '')

retries = Retry(total=10, backoff_factor=1, status_forcelist=[429])
SESSION.mount('https://', HTTPAdapter(max_retries=retries))

# %%
class PGConn:
    def __init__(self, host, port, dbname, user=None, passwd=None):
        self.host = host
        self.port = port
        self.dbname = dbname
        if user is not None:
            self.user = user
        else:
            self.user = ""
        if passwd is not None:
            self.passwd = passwd
        else:
            self.passwd = ""
        self.conn = None

    def connection(self):
        """Return connection to PostgreSQL.  It does not need to be closed
        explicitly.  See the destructor definition below.

        """
        if self.conn is None:
            conn = psycopg2.connect(dbname=self.dbname,
                                    host=self.host,
                                    port=str(self.port),
                                    user=self.user,
                                    password=self.passwd)
            self.conn = conn
            
        return self.conn

    def __del__(self):
        """No need to explicitly close the connection.  It will be closed when
        the PGConn object is garbage collected by Python runtime.

        """
        print(self.conn)
        self.conn.close()
        self.conn = None

pgconn_obj = PGConn(
    "localhost",
    5432,
    "dolr",
    "sameer",
    "swimgood"
)
    
pgconn=pgconn_obj.connection()

sql_query = f"""
    select
        st_astext(st_transform(geom, 4674)) as geom_text
    from
        pilot.dagdagad_farmplots_dedup
    where
        gid = 1
    ;
"""

with pgconn.cursor() as curs:
    curs.execute(sql_query)
    poly_fetch = curs.fetchone()[0]

poly_split = poly_fetch.split('(')
poly_coords = poly_split[3]
poly_coords = poly_coords.split(')')[0]
poly_point_coords = poly_coords.split(',')

points = []
for pt_coords in poly_point_coords:
    pt_split = pt_coords.split(' ')
    lat = float(pt_split[0])
    long = float(pt_split[1])
    points.append([lat, long])
print(points)

pgconn_obj.__del__()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# Cell In[6], line 61
#      50 sql_query = f"""
#      51     select
#      52         st_astext(st_transform(geom, 4674)) as geom_text
#    (...)
#      57     ;
#      58 """
#      60 with pgconn.cursor() as curs:
# ---> 61     curs.execute(sql_query)
#      62     poly_fetch = curs.fetchone()[0]
#      64 poly_split = poly_fetch.split('(')
#
# UndefinedTable: relation "dagdagad.farmplots_dedup" does not exist
# LINE 5:         dagdagad.farmplots_dedup
#                 ^

# %%
def place_monthly_order(mosaic_name, points):
    order_params = {
        "name": "Basemap order with geometry",
        "source_type": "basemaps",
        "products": [
            {
                "mosaic_name": mosaic_name,
                "geometry":{
                "type": "Polygon",
                "coordinates":[
                    points
                ]
                }
            }
        ]
    }
    
    paramRes = requests.post(ORDERS_API_URL,
        data=json.dumps(order_params),
        auth=AUTH,
        headers={'content-type': 'application/json'}
    )

    print(paramRes.text)

    order_id = paramRes.json()['id']
    order_url = ORDERS_API_URL + '/' + order_id
    return order_url

def poll_for_success(order_url, num_loops=30):
    count = 0
    while(count < num_loops):
        count += 1
        r = requests.get(order_url, auth=AUTH)
        response = r.json()
        state = response['state']
        print(state)
        end_states = ['success', 'failed', 'partial']
        if state in end_states:
            break
        time.sleep(10)

def download_results(results, overwrite=False):
    results_urls = [r['location'] for r in results]
    results_names = [r['name'] for r in results]
    print('{} items to download'.format(len(results_urls)))
    
    for url, name in zip(results_urls, results_names):
        path = pathlib.Path(os.path.join('data', name))
        
        if overwrite or not path.exists():
            print('downloading {} to {}'.format(name, path))
            r = requests.get(url, allow_redirects=True)
            path.parent.mkdir(parents=True, exist_ok=True)
            open(path, 'wb').write(r.content)
        else:
            print('{} already exists, skipping {}'.format(path, name))

# %%
order_urls = []
for month in range(1, 13):
    if month < 10:
        month = "0" + str(month)
    else:
        month = str(month)
    mosaic_name = f"global_monthly_2022_{month}_mosaic"
    order_url = place_monthly_order(mosaic_name, points)
    order_urls.append(order_url)
# Out:
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/0284429d-3a55-4e73-9e98-020164e0f6f1"},"created_on":"2024-01-14T16:59:48.525Z","error_hints":[],"id":"0284429d-3a55-4e73-9e98-020164e0f6f1","last_message":"Preparing order","last_modified":"2024-01-14T16:59:48.525Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_01_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/603761e4-c5a9-446a-9a87-de62f202d4d9"},"created_on":"2024-01-14T16:59:49.389Z","error_hints":[],"id":"603761e4-c5a9-446a-9a87-de62f202d4d9","last_message":"Preparing order","last_modified":"2024-01-14T16:59:49.389Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_02_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/37a61e21-3403-4afa-af94-2f08830e10aa"},"created_on":"2024-01-14T16:59:50.352Z","error_hints":[],"id":"37a61e21-3403-4afa-af94-2f08830e10aa","last_message":"Preparing order","last_modified":"2024-01-14T16:59:50.352Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_03_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/ed088f8a-d74d-4e6e-b083-cdfb0600363a"},"created_on":"2024-01-14T16:59:51.081Z","error_hints":[],"id":"ed088f8a-d74d-4e6e-b083-cdfb0600363a","last_message":"Preparing order","last_modified":"2024-01-14T16:59:51.081Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_04_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/e75c4dc4-08ed-4f94-aaeb-4c35718478ad"},"created_on":"2024-01-14T16:59:51.934Z","error_hints":[],"id":"e75c4dc4-08ed-4f94-aaeb-4c35718478ad","last_message":"Preparing order","last_modified":"2024-01-14T16:59:51.934Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_05_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/ffe546a2-c45a-4f41-bbe1-bebe765e0927"},"created_on":"2024-01-14T16:59:53.017Z","error_hints":[],"id":"ffe546a2-c45a-4f41-bbe1-bebe765e0927","last_message":"Preparing order","last_modified":"2024-01-14T16:59:53.017Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_06_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/59aee595-876a-4cde-869d-18dab14b909c"},"created_on":"2024-01-14T16:59:53.672Z","error_hints":[],"id":"59aee595-876a-4cde-869d-18dab14b909c","last_message":"Preparing order","last_modified":"2024-01-14T16:59:53.672Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_07_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/25e3283d-0f65-4bc2-a4e1-4cde9173077c"},"created_on":"2024-01-14T16:59:54.502Z","error_hints":[],"id":"25e3283d-0f65-4bc2-a4e1-4cde9173077c","last_message":"Preparing order","last_modified":"2024-01-14T16:59:54.502Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_08_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/8fa03de8-d3e8-465f-b57c-6b9839afee42"},"created_on":"2024-01-14T16:59:55.300Z","error_hints":[],"id":"8fa03de8-d3e8-465f-b57c-6b9839afee42","last_message":"Preparing order","last_modified":"2024-01-14T16:59:55.300Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_09_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/951fbee1-6d5d-4378-8c0f-bbf3299e5246"},"created_on":"2024-01-14T16:59:56.052Z","error_hints":[],"id":"951fbee1-6d5d-4378-8c0f-bbf3299e5246","last_message":"Preparing order","last_modified":"2024-01-14T16:59:56.052Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_10_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/706c11f8-edc3-4e27-aa8d-10b323b3a204"},"created_on":"2024-01-14T16:59:56.833Z","error_hints":[],"id":"706c11f8-edc3-4e27-aa8d-10b323b3a204","last_message":"Preparing order","last_modified":"2024-01-14T16:59:56.833Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_11_mosaic"}],"source_type":"basemaps","state":"queued"}
#
# {"_links":{"_self":"https://api.planet.com/compute/ops/orders/v2/e16ae81b-035a-449d-8655-ba676bea4dc2"},"created_on":"2024-01-14T16:59:57.557Z","error_hints":[],"id":"e16ae81b-035a-449d-8655-ba676bea4dc2","last_message":"Preparing order","last_modified":"2024-01-14T16:59:57.557Z","name":"Basemap order with geometry","products":[{"geometry":{"coordinates":[[[77.6226544,21.0217687],[77.6226003,21.0208757],[77.6221296,21.020901],[77.6222195,21.0221907],[77.622699,21.022120099999995],[77.6226544,21.0217687]]],"type":"Polygon"},"mosaic_name":"global_monthly_2023_12_mosaic"}],"source_type":"basemaps","state":"queued"}

# %%
for order_url in order_urls:
    poll_for_success(order_url)
    r = requests.get(order_url, auth=AUTH)
    response = r.json()
    results = response['_links']['results']
    print([r['name'] for r in results])
    download_results(results)
# Out:
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# ['0284429d-3a55-4e73-9e98-020164e0f6f1/global_monthly_2023_01_mosaic/1465-1146_quad.tif', '0284429d-3a55-4e73-9e98-020164e0f6f1/global_monthly_2023_01_mosaic/1465-1146_provenance_vector.zip', '0284429d-3a55-4e73-9e98-020164e0f6f1/global_monthly_2023_01_mosaic/1465-1146_provenance_raster.tif', '0284429d-3a55-4e73-9e98-020164e0f6f1/global_monthly_2023_01_mosaic/1465-1146_ortho_udm2.tif', '0284429d-3a55-4e73-9e98-020164e0f6f1/global_monthly_2023_01_mosaic/1465-1146_metadata.json']
# 5 items to download
# downloading 0284429d-3a55-4e73-9e98-020164e0f6f1/global_monthly_2023_01_mosaic/1465-1146_quad.tif to data\0284429d-3a55-4e73-9e98-020164e0f6f1\global_monthly_2023_01_mosaic\1465-1146_quad.tif
# downloading 0284429d-3a55-4e73-9e98-020164e0f6f1/global_monthly_2023_01_mosaic/1465-1146_provenance_vector.zip to data\0284429d-3a55-4e73-9e98-020164e0f6f1\global_monthly_2023_01_mosaic\1465-1146_provenance_vector.zip
# downloading 0284429d-3a55-4e73-9e98-020164e0f6f1/global_monthly_2023_01_mosaic/1465-1146_provenance_raster.tif to data\0284429d-3a55-4e73-9e98-020164e0f6f1\global_monthly_2023_01_mosaic\1465-1146_provenance_raster.tif
# downloading 0284429d-3a55-4e73-9e98-020164e0f6f1/global_monthly_2023_01_mosaic/1465-1146_ortho_udm2.tif to data\0284429d-3a55-4e73-9e98-020164e0f6f1\global_monthly_2023_01_mosaic\1465-1146_ortho_udm2.tif
# downloading 0284429d-3a55-4e73-9e98-020164e0f6f1/global_monthly_2023_01_mosaic/1465-1146_metadata.json to data\0284429d-3a55-4e73-9e98-020164e0f6f1\global_monthly_2023_01_mosaic\1465-1146_metadata.json
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# success
# ['603761e4-c5a9-446a-9a87-de62f202d4d9/global_monthly_2023_02_mosaic/1465-1146_quad.tif', '603761e4-c5a9-446a-9a87-de62f202d4d9/global_monthly_2023_02_mosaic/1465-1146_provenance_vector.zip', '603761e4-c5a9-446a-9a87-de62f202d4d9/global_monthly_2023_02_mosaic/1465-1146_provenance_raster.tif', '603761e4-c5a9-446a-9a87-de62f202d4d9/global_monthly_2023_02_mosaic/1465-1146_ortho_udm2.tif', '603761e4-c5a9-446a-9a87-de62f202d4d9/global_monthly_2023_02_mosaic/1465-1146_metadata.json', '603761e4-c5a9-446a-9a87-de62f202d4d9/manifest.json']
# 6 items to download
# downloading 603761e4-c5a9-446a-9a87-de62f202d4d9/global_monthly_2023_02_mosaic/1465-1146_quad.tif to data\603761e4-c5a9-446a-9a87-de62f202d4d9\global_monthly_2023_02_mosaic\1465-1146_quad.tif
# downloading 603761e4-c5a9-446a-9a87-de62f202d4d9/global_monthly_2023_02_mosaic/1465-1146_provenance_vector.zip to data\603761e4-c5a9-446a-9a87-de62f202d4d9\global_monthly_2023_02_mosaic\1465-1146_provenance_vector.zip
# downloading 603761e4-c5a9-446a-9a87-de62f202d4d9/global_monthly_2023_02_mosaic/1465-1146_provenance_raster.tif to data\603761e4-c5a9-446a-9a87-de62f202d4d9\global_monthly_2023_02_mosaic\1465-1146_provenance_raster.tif
# downloading 603761e4-c5a9-446a-9a87-de62f202d4d9/global_monthly_2023_02_mosaic/1465-1146_ortho_udm2.tif to data\603761e4-c5a9-446a-9a87-de62f202d4d9\global_monthly_2023_02_mosaic\1465-1146_ortho_udm2.tif
# downloading 603761e4-c5a9-446a-9a87-de62f202d4d9/global_monthly_2023_02_mosaic/1465-1146_metadata.json to data\603761e4-c5a9-446a-9a87-de62f202d4d9\global_monthly_2023_02_mosaic\1465-1146_metadata.json
# downloading 603761e4-c5a9-446a-9a87-de62f202d4d9/manifest.json to data\603761e4-c5a9-446a-9a87-de62f202d4d9\manifest.json
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# success
# ['37a61e21-3403-4afa-af94-2f08830e10aa/global_monthly_2023_03_mosaic/1465-1146_quad.tif', '37a61e21-3403-4afa-af94-2f08830e10aa/global_monthly_2023_03_mosaic/1465-1146_provenance_vector.zip', '37a61e21-3403-4afa-af94-2f08830e10aa/global_monthly_2023_03_mosaic/1465-1146_provenance_raster.tif', '37a61e21-3403-4afa-af94-2f08830e10aa/global_monthly_2023_03_mosaic/1465-1146_ortho_udm2.tif', '37a61e21-3403-4afa-af94-2f08830e10aa/global_monthly_2023_03_mosaic/1465-1146_metadata.json', '37a61e21-3403-4afa-af94-2f08830e10aa/manifest.json']
# 6 items to download
# downloading 37a61e21-3403-4afa-af94-2f08830e10aa/global_monthly_2023_03_mosaic/1465-1146_quad.tif to data\37a61e21-3403-4afa-af94-2f08830e10aa\global_monthly_2023_03_mosaic\1465-1146_quad.tif
# downloading 37a61e21-3403-4afa-af94-2f08830e10aa/global_monthly_2023_03_mosaic/1465-1146_provenance_vector.zip to data\37a61e21-3403-4afa-af94-2f08830e10aa\global_monthly_2023_03_mosaic\1465-1146_provenance_vector.zip
# downloading 37a61e21-3403-4afa-af94-2f08830e10aa/global_monthly_2023_03_mosaic/1465-1146_provenance_raster.tif to data\37a61e21-3403-4afa-af94-2f08830e10aa\global_monthly_2023_03_mosaic\1465-1146_provenance_raster.tif
# downloading 37a61e21-3403-4afa-af94-2f08830e10aa/global_monthly_2023_03_mosaic/1465-1146_ortho_udm2.tif to data\37a61e21-3403-4afa-af94-2f08830e10aa\global_monthly_2023_03_mosaic\1465-1146_ortho_udm2.tif
# downloading 37a61e21-3403-4afa-af94-2f08830e10aa/global_monthly_2023_03_mosaic/1465-1146_metadata.json to data\37a61e21-3403-4afa-af94-2f08830e10aa\global_monthly_2023_03_mosaic\1465-1146_metadata.json
# downloading 37a61e21-3403-4afa-af94-2f08830e10aa/manifest.json to data\37a61e21-3403-4afa-af94-2f08830e10aa\manifest.json
# success
# ['ed088f8a-d74d-4e6e-b083-cdfb0600363a/global_monthly_2023_04_mosaic/1465-1146_quad.tif', 'ed088f8a-d74d-4e6e-b083-cdfb0600363a/global_monthly_2023_04_mosaic/1465-1146_provenance_vector.zip', 'ed088f8a-d74d-4e6e-b083-cdfb0600363a/global_monthly_2023_04_mosaic/1465-1146_provenance_raster.tif', 'ed088f8a-d74d-4e6e-b083-cdfb0600363a/global_monthly_2023_04_mosaic/1465-1146_ortho_udm2.tif', 'ed088f8a-d74d-4e6e-b083-cdfb0600363a/global_monthly_2023_04_mosaic/1465-1146_metadata.json', 'ed088f8a-d74d-4e6e-b083-cdfb0600363a/manifest.json']
# 6 items to download
# downloading ed088f8a-d74d-4e6e-b083-cdfb0600363a/global_monthly_2023_04_mosaic/1465-1146_quad.tif to data\ed088f8a-d74d-4e6e-b083-cdfb0600363a\global_monthly_2023_04_mosaic\1465-1146_quad.tif
# downloading ed088f8a-d74d-4e6e-b083-cdfb0600363a/global_monthly_2023_04_mosaic/1465-1146_provenance_vector.zip to data\ed088f8a-d74d-4e6e-b083-cdfb0600363a\global_monthly_2023_04_mosaic\1465-1146_provenance_vector.zip
# downloading ed088f8a-d74d-4e6e-b083-cdfb0600363a/global_monthly_2023_04_mosaic/1465-1146_provenance_raster.tif to data\ed088f8a-d74d-4e6e-b083-cdfb0600363a\global_monthly_2023_04_mosaic\1465-1146_provenance_raster.tif
# downloading ed088f8a-d74d-4e6e-b083-cdfb0600363a/global_monthly_2023_04_mosaic/1465-1146_ortho_udm2.tif to data\ed088f8a-d74d-4e6e-b083-cdfb0600363a\global_monthly_2023_04_mosaic\1465-1146_ortho_udm2.tif
# downloading ed088f8a-d74d-4e6e-b083-cdfb0600363a/global_monthly_2023_04_mosaic/1465-1146_metadata.json to data\ed088f8a-d74d-4e6e-b083-cdfb0600363a\global_monthly_2023_04_mosaic\1465-1146_metadata.json
# downloading ed088f8a-d74d-4e6e-b083-cdfb0600363a/manifest.json to data\ed088f8a-d74d-4e6e-b083-cdfb0600363a\manifest.json
# success
# ['e75c4dc4-08ed-4f94-aaeb-4c35718478ad/global_monthly_2023_05_mosaic/1465-1146_quad.tif', 'e75c4dc4-08ed-4f94-aaeb-4c35718478ad/global_monthly_2023_05_mosaic/1465-1146_provenance_vector.zip', 'e75c4dc4-08ed-4f94-aaeb-4c35718478ad/global_monthly_2023_05_mosaic/1465-1146_provenance_raster.tif', 'e75c4dc4-08ed-4f94-aaeb-4c35718478ad/global_monthly_2023_05_mosaic/1465-1146_ortho_udm2.tif', 'e75c4dc4-08ed-4f94-aaeb-4c35718478ad/global_monthly_2023_05_mosaic/1465-1146_metadata.json', 'e75c4dc4-08ed-4f94-aaeb-4c35718478ad/manifest.json']
# 6 items to download
# downloading e75c4dc4-08ed-4f94-aaeb-4c35718478ad/global_monthly_2023_05_mosaic/1465-1146_quad.tif to data\e75c4dc4-08ed-4f94-aaeb-4c35718478ad\global_monthly_2023_05_mosaic\1465-1146_quad.tif
# downloading e75c4dc4-08ed-4f94-aaeb-4c35718478ad/global_monthly_2023_05_mosaic/1465-1146_provenance_vector.zip to data\e75c4dc4-08ed-4f94-aaeb-4c35718478ad\global_monthly_2023_05_mosaic\1465-1146_provenance_vector.zip
# downloading e75c4dc4-08ed-4f94-aaeb-4c35718478ad/global_monthly_2023_05_mosaic/1465-1146_provenance_raster.tif to data\e75c4dc4-08ed-4f94-aaeb-4c35718478ad\global_monthly_2023_05_mosaic\1465-1146_provenance_raster.tif
# downloading e75c4dc4-08ed-4f94-aaeb-4c35718478ad/global_monthly_2023_05_mosaic/1465-1146_ortho_udm2.tif to data\e75c4dc4-08ed-4f94-aaeb-4c35718478ad\global_monthly_2023_05_mosaic\1465-1146_ortho_udm2.tif
# downloading e75c4dc4-08ed-4f94-aaeb-4c35718478ad/global_monthly_2023_05_mosaic/1465-1146_metadata.json to data\e75c4dc4-08ed-4f94-aaeb-4c35718478ad\global_monthly_2023_05_mosaic\1465-1146_metadata.json
# downloading e75c4dc4-08ed-4f94-aaeb-4c35718478ad/manifest.json to data\e75c4dc4-08ed-4f94-aaeb-4c35718478ad\manifest.json
# success
# ['ffe546a2-c45a-4f41-bbe1-bebe765e0927/global_monthly_2023_06_mosaic/1465-1146_quad.tif', 'ffe546a2-c45a-4f41-bbe1-bebe765e0927/global_monthly_2023_06_mosaic/1465-1146_provenance_vector.zip', 'ffe546a2-c45a-4f41-bbe1-bebe765e0927/global_monthly_2023_06_mosaic/1465-1146_provenance_raster.tif', 'ffe546a2-c45a-4f41-bbe1-bebe765e0927/global_monthly_2023_06_mosaic/1465-1146_ortho_udm2.tif', 'ffe546a2-c45a-4f41-bbe1-bebe765e0927/global_monthly_2023_06_mosaic/1465-1146_metadata.json', 'ffe546a2-c45a-4f41-bbe1-bebe765e0927/manifest.json']
# 6 items to download
# downloading ffe546a2-c45a-4f41-bbe1-bebe765e0927/global_monthly_2023_06_mosaic/1465-1146_quad.tif to data\ffe546a2-c45a-4f41-bbe1-bebe765e0927\global_monthly_2023_06_mosaic\1465-1146_quad.tif
# downloading ffe546a2-c45a-4f41-bbe1-bebe765e0927/global_monthly_2023_06_mosaic/1465-1146_provenance_vector.zip to data\ffe546a2-c45a-4f41-bbe1-bebe765e0927\global_monthly_2023_06_mosaic\1465-1146_provenance_vector.zip
# downloading ffe546a2-c45a-4f41-bbe1-bebe765e0927/global_monthly_2023_06_mosaic/1465-1146_provenance_raster.tif to data\ffe546a2-c45a-4f41-bbe1-bebe765e0927\global_monthly_2023_06_mosaic\1465-1146_provenance_raster.tif
# downloading ffe546a2-c45a-4f41-bbe1-bebe765e0927/global_monthly_2023_06_mosaic/1465-1146_ortho_udm2.tif to data\ffe546a2-c45a-4f41-bbe1-bebe765e0927\global_monthly_2023_06_mosaic\1465-1146_ortho_udm2.tif
# downloading ffe546a2-c45a-4f41-bbe1-bebe765e0927/global_monthly_2023_06_mosaic/1465-1146_metadata.json to data\ffe546a2-c45a-4f41-bbe1-bebe765e0927\global_monthly_2023_06_mosaic\1465-1146_metadata.json
# downloading ffe546a2-c45a-4f41-bbe1-bebe765e0927/manifest.json to data\ffe546a2-c45a-4f41-bbe1-bebe765e0927\manifest.json
# success
# ['59aee595-876a-4cde-869d-18dab14b909c/global_monthly_2023_07_mosaic/1465-1146_quad.tif', '59aee595-876a-4cde-869d-18dab14b909c/global_monthly_2023_07_mosaic/1465-1146_provenance_vector.zip', '59aee595-876a-4cde-869d-18dab14b909c/global_monthly_2023_07_mosaic/1465-1146_provenance_raster.tif', '59aee595-876a-4cde-869d-18dab14b909c/global_monthly_2023_07_mosaic/1465-1146_ortho_udm2.tif', '59aee595-876a-4cde-869d-18dab14b909c/global_monthly_2023_07_mosaic/1465-1146_metadata.json', '59aee595-876a-4cde-869d-18dab14b909c/manifest.json']
# 6 items to download
# downloading 59aee595-876a-4cde-869d-18dab14b909c/global_monthly_2023_07_mosaic/1465-1146_quad.tif to data\59aee595-876a-4cde-869d-18dab14b909c\global_monthly_2023_07_mosaic\1465-1146_quad.tif
# downloading 59aee595-876a-4cde-869d-18dab14b909c/global_monthly_2023_07_mosaic/1465-1146_provenance_vector.zip to data\59aee595-876a-4cde-869d-18dab14b909c\global_monthly_2023_07_mosaic\1465-1146_provenance_vector.zip
# downloading 59aee595-876a-4cde-869d-18dab14b909c/global_monthly_2023_07_mosaic/1465-1146_provenance_raster.tif to data\59aee595-876a-4cde-869d-18dab14b909c\global_monthly_2023_07_mosaic\1465-1146_provenance_raster.tif
# downloading 59aee595-876a-4cde-869d-18dab14b909c/global_monthly_2023_07_mosaic/1465-1146_ortho_udm2.tif to data\59aee595-876a-4cde-869d-18dab14b909c\global_monthly_2023_07_mosaic\1465-1146_ortho_udm2.tif
# downloading 59aee595-876a-4cde-869d-18dab14b909c/global_monthly_2023_07_mosaic/1465-1146_metadata.json to data\59aee595-876a-4cde-869d-18dab14b909c\global_monthly_2023_07_mosaic\1465-1146_metadata.json
# downloading 59aee595-876a-4cde-869d-18dab14b909c/manifest.json to data\59aee595-876a-4cde-869d-18dab14b909c\manifest.json
# success
# ['25e3283d-0f65-4bc2-a4e1-4cde9173077c/global_monthly_2023_08_mosaic/1465-1146_quad.tif', '25e3283d-0f65-4bc2-a4e1-4cde9173077c/global_monthly_2023_08_mosaic/1465-1146_provenance_vector.zip', '25e3283d-0f65-4bc2-a4e1-4cde9173077c/global_monthly_2023_08_mosaic/1465-1146_provenance_raster.tif', '25e3283d-0f65-4bc2-a4e1-4cde9173077c/global_monthly_2023_08_mosaic/1465-1146_ortho_udm2.tif', '25e3283d-0f65-4bc2-a4e1-4cde9173077c/global_monthly_2023_08_mosaic/1465-1146_metadata.json', '25e3283d-0f65-4bc2-a4e1-4cde9173077c/manifest.json']
# 6 items to download
# downloading 25e3283d-0f65-4bc2-a4e1-4cde9173077c/global_monthly_2023_08_mosaic/1465-1146_quad.tif to data\25e3283d-0f65-4bc2-a4e1-4cde9173077c\global_monthly_2023_08_mosaic\1465-1146_quad.tif
# downloading 25e3283d-0f65-4bc2-a4e1-4cde9173077c/global_monthly_2023_08_mosaic/1465-1146_provenance_vector.zip to data\25e3283d-0f65-4bc2-a4e1-4cde9173077c\global_monthly_2023_08_mosaic\1465-1146_provenance_vector.zip
# downloading 25e3283d-0f65-4bc2-a4e1-4cde9173077c/global_monthly_2023_08_mosaic/1465-1146_provenance_raster.tif to data\25e3283d-0f65-4bc2-a4e1-4cde9173077c\global_monthly_2023_08_mosaic\1465-1146_provenance_raster.tif
# downloading 25e3283d-0f65-4bc2-a4e1-4cde9173077c/global_monthly_2023_08_mosaic/1465-1146_ortho_udm2.tif to data\25e3283d-0f65-4bc2-a4e1-4cde9173077c\global_monthly_2023_08_mosaic\1465-1146_ortho_udm2.tif
# downloading 25e3283d-0f65-4bc2-a4e1-4cde9173077c/global_monthly_2023_08_mosaic/1465-1146_metadata.json to data\25e3283d-0f65-4bc2-a4e1-4cde9173077c\global_monthly_2023_08_mosaic\1465-1146_metadata.json
# downloading 25e3283d-0f65-4bc2-a4e1-4cde9173077c/manifest.json to data\25e3283d-0f65-4bc2-a4e1-4cde9173077c\manifest.json
# success
# ['8fa03de8-d3e8-465f-b57c-6b9839afee42/global_monthly_2023_09_mosaic/1465-1146_quad.tif', '8fa03de8-d3e8-465f-b57c-6b9839afee42/global_monthly_2023_09_mosaic/1465-1146_provenance_vector.zip', '8fa03de8-d3e8-465f-b57c-6b9839afee42/global_monthly_2023_09_mosaic/1465-1146_provenance_raster.tif', '8fa03de8-d3e8-465f-b57c-6b9839afee42/global_monthly_2023_09_mosaic/1465-1146_ortho_udm2.tif', '8fa03de8-d3e8-465f-b57c-6b9839afee42/global_monthly_2023_09_mosaic/1465-1146_metadata.json', '8fa03de8-d3e8-465f-b57c-6b9839afee42/manifest.json']
# 6 items to download
# downloading 8fa03de8-d3e8-465f-b57c-6b9839afee42/global_monthly_2023_09_mosaic/1465-1146_quad.tif to data\8fa03de8-d3e8-465f-b57c-6b9839afee42\global_monthly_2023_09_mosaic\1465-1146_quad.tif
# downloading 8fa03de8-d3e8-465f-b57c-6b9839afee42/global_monthly_2023_09_mosaic/1465-1146_provenance_vector.zip to data\8fa03de8-d3e8-465f-b57c-6b9839afee42\global_monthly_2023_09_mosaic\1465-1146_provenance_vector.zip
# downloading 8fa03de8-d3e8-465f-b57c-6b9839afee42/global_monthly_2023_09_mosaic/1465-1146_provenance_raster.tif to data\8fa03de8-d3e8-465f-b57c-6b9839afee42\global_monthly_2023_09_mosaic\1465-1146_provenance_raster.tif
# downloading 8fa03de8-d3e8-465f-b57c-6b9839afee42/global_monthly_2023_09_mosaic/1465-1146_ortho_udm2.tif to data\8fa03de8-d3e8-465f-b57c-6b9839afee42\global_monthly_2023_09_mosaic\1465-1146_ortho_udm2.tif
# downloading 8fa03de8-d3e8-465f-b57c-6b9839afee42/global_monthly_2023_09_mosaic/1465-1146_metadata.json to data\8fa03de8-d3e8-465f-b57c-6b9839afee42\global_monthly_2023_09_mosaic\1465-1146_metadata.json
# downloading 8fa03de8-d3e8-465f-b57c-6b9839afee42/manifest.json to data\8fa03de8-d3e8-465f-b57c-6b9839afee42\manifest.json
# success
# ['951fbee1-6d5d-4378-8c0f-bbf3299e5246/global_monthly_2023_10_mosaic/1465-1146_quad.tif', '951fbee1-6d5d-4378-8c0f-bbf3299e5246/global_monthly_2023_10_mosaic/1465-1146_provenance_vector.zip', '951fbee1-6d5d-4378-8c0f-bbf3299e5246/global_monthly_2023_10_mosaic/1465-1146_provenance_raster.tif', '951fbee1-6d5d-4378-8c0f-bbf3299e5246/global_monthly_2023_10_mosaic/1465-1146_ortho_udm2.tif', '951fbee1-6d5d-4378-8c0f-bbf3299e5246/global_monthly_2023_10_mosaic/1465-1146_metadata.json', '951fbee1-6d5d-4378-8c0f-bbf3299e5246/manifest.json']
# 6 items to download
# downloading 951fbee1-6d5d-4378-8c0f-bbf3299e5246/global_monthly_2023_10_mosaic/1465-1146_quad.tif to data\951fbee1-6d5d-4378-8c0f-bbf3299e5246\global_monthly_2023_10_mosaic\1465-1146_quad.tif
# downloading 951fbee1-6d5d-4378-8c0f-bbf3299e5246/global_monthly_2023_10_mosaic/1465-1146_provenance_vector.zip to data\951fbee1-6d5d-4378-8c0f-bbf3299e5246\global_monthly_2023_10_mosaic\1465-1146_provenance_vector.zip
# downloading 951fbee1-6d5d-4378-8c0f-bbf3299e5246/global_monthly_2023_10_mosaic/1465-1146_provenance_raster.tif to data\951fbee1-6d5d-4378-8c0f-bbf3299e5246\global_monthly_2023_10_mosaic\1465-1146_provenance_raster.tif
# downloading 951fbee1-6d5d-4378-8c0f-bbf3299e5246/global_monthly_2023_10_mosaic/1465-1146_ortho_udm2.tif to data\951fbee1-6d5d-4378-8c0f-bbf3299e5246\global_monthly_2023_10_mosaic\1465-1146_ortho_udm2.tif
# downloading 951fbee1-6d5d-4378-8c0f-bbf3299e5246/global_monthly_2023_10_mosaic/1465-1146_metadata.json to data\951fbee1-6d5d-4378-8c0f-bbf3299e5246\global_monthly_2023_10_mosaic\1465-1146_metadata.json
# downloading 951fbee1-6d5d-4378-8c0f-bbf3299e5246/manifest.json to data\951fbee1-6d5d-4378-8c0f-bbf3299e5246\manifest.json
# success
# ['706c11f8-edc3-4e27-aa8d-10b323b3a204/global_monthly_2023_11_mosaic/1465-1146_quad.tif', '706c11f8-edc3-4e27-aa8d-10b323b3a204/global_monthly_2023_11_mosaic/1465-1146_provenance_vector.zip', '706c11f8-edc3-4e27-aa8d-10b323b3a204/global_monthly_2023_11_mosaic/1465-1146_provenance_raster.tif', '706c11f8-edc3-4e27-aa8d-10b323b3a204/global_monthly_2023_11_mosaic/1465-1146_ortho_udm2.tif', '706c11f8-edc3-4e27-aa8d-10b323b3a204/global_monthly_2023_11_mosaic/1465-1146_metadata.json', '706c11f8-edc3-4e27-aa8d-10b323b3a204/manifest.json']
# 6 items to download
# downloading 706c11f8-edc3-4e27-aa8d-10b323b3a204/global_monthly_2023_11_mosaic/1465-1146_quad.tif to data\706c11f8-edc3-4e27-aa8d-10b323b3a204\global_monthly_2023_11_mosaic\1465-1146_quad.tif
# downloading 706c11f8-edc3-4e27-aa8d-10b323b3a204/global_monthly_2023_11_mosaic/1465-1146_provenance_vector.zip to data\706c11f8-edc3-4e27-aa8d-10b323b3a204\global_monthly_2023_11_mosaic\1465-1146_provenance_vector.zip
# downloading 706c11f8-edc3-4e27-aa8d-10b323b3a204/global_monthly_2023_11_mosaic/1465-1146_provenance_raster.tif to data\706c11f8-edc3-4e27-aa8d-10b323b3a204\global_monthly_2023_11_mosaic\1465-1146_provenance_raster.tif
# downloading 706c11f8-edc3-4e27-aa8d-10b323b3a204/global_monthly_2023_11_mosaic/1465-1146_ortho_udm2.tif to data\706c11f8-edc3-4e27-aa8d-10b323b3a204\global_monthly_2023_11_mosaic\1465-1146_ortho_udm2.tif
# downloading 706c11f8-edc3-4e27-aa8d-10b323b3a204/global_monthly_2023_11_mosaic/1465-1146_metadata.json to data\706c11f8-edc3-4e27-aa8d-10b323b3a204\global_monthly_2023_11_mosaic\1465-1146_metadata.json
# downloading 706c11f8-edc3-4e27-aa8d-10b323b3a204/manifest.json to data\706c11f8-edc3-4e27-aa8d-10b323b3a204\manifest.json
# success
# ['e16ae81b-035a-449d-8655-ba676bea4dc2/global_monthly_2023_12_mosaic/1465-1146_quad.tif', 'e16ae81b-035a-449d-8655-ba676bea4dc2/global_monthly_2023_12_mosaic/1465-1146_provenance_vector.zip', 'e16ae81b-035a-449d-8655-ba676bea4dc2/global_monthly_2023_12_mosaic/1465-1146_provenance_raster.tif', 'e16ae81b-035a-449d-8655-ba676bea4dc2/global_monthly_2023_12_mosaic/1465-1146_ortho_udm2.tif', 'e16ae81b-035a-449d-8655-ba676bea4dc2/global_monthly_2023_12_mosaic/1465-1146_metadata.json', 'e16ae81b-035a-449d-8655-ba676bea4dc2/manifest.json']
# 6 items to download
# downloading e16ae81b-035a-449d-8655-ba676bea4dc2/global_monthly_2023_12_mosaic/1465-1146_quad.tif to data\e16ae81b-035a-449d-8655-ba676bea4dc2\global_monthly_2023_12_mosaic\1465-1146_quad.tif
# downloading e16ae81b-035a-449d-8655-ba676bea4dc2/global_monthly_2023_12_mosaic/1465-1146_provenance_vector.zip to data\e16ae81b-035a-449d-8655-ba676bea4dc2\global_monthly_2023_12_mosaic\1465-1146_provenance_vector.zip
# downloading e16ae81b-035a-449d-8655-ba676bea4dc2/global_monthly_2023_12_mosaic/1465-1146_provenance_raster.tif to data\e16ae81b-035a-449d-8655-ba676bea4dc2\global_monthly_2023_12_mosaic\1465-1146_provenance_raster.tif
# downloading e16ae81b-035a-449d-8655-ba676bea4dc2/global_monthly_2023_12_mosaic/1465-1146_ortho_udm2.tif to data\e16ae81b-035a-449d-8655-ba676bea4dc2\global_monthly_2023_12_mosaic\1465-1146_ortho_udm2.tif
# downloading e16ae81b-035a-449d-8655-ba676bea4dc2/global_monthly_2023_12_mosaic/1465-1146_metadata.json to data\e16ae81b-035a-449d-8655-ba676bea4dc2\global_monthly_2023_12_mosaic\1465-1146_metadata.json
# downloading e16ae81b-035a-449d-8655-ba676bea4dc2/manifest.json to data\e16ae81b-035a-449d-8655-ba676bea4dc2\manifest.json
